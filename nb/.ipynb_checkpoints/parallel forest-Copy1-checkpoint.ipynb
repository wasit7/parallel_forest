# %% [markdown]
# #Parallel Forest Tutorial
# This notebooke show the traing process of Parallel Random Forest. For cluster training please check https://github.com/wasit7/parallel_forest
#
# ## import modules
# Import all necessary modules

# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Generating datasets

# %%
clmax=5
spc=1e2
theta_range=2
#samples is list of labels
samples=np.zeros(spc*clmax,dtype=np.uint32)
#I is fessture vector
I=np.zeros((spc*clmax,theta_range),dtype=np.float32)
marker=['bo','co','go','ro','mo','yo','ko',
        'bs','cs','gs','rs','ms','ys','ks']

# number of datasets being generated 
# 8 for training
# another one for evaluation
N=9 
path="myTrain"
if not os.path.exists(path):
    os.makedirs(path)
for n in xrange(N):
    for cl in xrange(clmax):
        xo=cl*spc
        #define label
        samples[xo:xo+spc]=cl
        phi = np.linspace(0, 2*np.pi, spc) + \
        np.random.randn(spc)*0.4*np.pi/clmax + \
        2*np.pi*cl/clmax
        r = np.linspace(0.1, 1, spc)
        I[xo:xo+spc,:]=np.transpose(np.array([r*np.cos(phi), r*np.sin(phi)]))
    with open(path+'/dataset%02d.pic'%(n), 'wb') as pickleFile:
    #write label and feature vector
        theta_dim=1
        pickle.dump((clmax,theta_dim,theta_range,len(samples),samples,I,None), pickleFile, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ##Visualization of the dataset

# %%
z=np.random.randint( 0,spc*clmax,1000)
for i in z:
    #ax.plot(dset.I[i,0],dset.I[i,1],marker[dset2.samples[i]])
    plt.plot(I[i,0],I[i,1],marker[samples[i]])
    plt.hold(True)

# %% [markdown]
# ##Training

# %%
from pforest.master import master
m=master(dsetname='myTrain')
m.reset()
m.train()
# Out:
# master>>init() dsetname: myTrain
# master>> create dview
# master>> init engine
# Found pforest
# debug:master:__init__: ['myTrain/dataset00.pic', 'myTrain/dataset01.pic', 'myTrain/dataset02.pic', 'myTrain/dataset03.pic', 'myTrain/dataset04.pic', 'myTrain/dataset05.pic', 'myTrain/dataset06.pic', 'myTrain/dataset07.pic']
# master>> init local variables
# master>>reset()
# master>>reset() H: 2.3219
# master>>reset() Q: 04000
# master::train() node20*-
# master::train() node19R-
# master::train() node18R-
# master::train() node17R-
# master::train() node16R-
# master::train() node15RG
# master::train() node15L-
# master::train() node14RG
# master::train() node14LQ
# master::train() node16L-
# master::train() node15R-
# master::train() node14RQ
# master::train() node14LQ
# master::train() node15LG
# master::train() node17L-
# master::train() node16R-
# master::train() node15RG
# master::train() node15LQ
# master::train() node16L-
# master::train() node15R-
# master::train() node14RG
# master::train() node14LG
# master::train() node15L-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RQ
# master::train() node13LQ
# master::train() node18L-
# master::train() node17R-
# master::train() node16RG
# master::train() node16L-
# master::train() node15RG
# master::train() node15LG
# master::train() node17L-
# master::train() node16R-
# master::train() node15R-
# master::train() node14R-
# master::train() node13RG
# master::train() node13L-
# master::train() node12RQ
# master::train() node12LQ
# master::train() node14L-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RQ
# master::train() node11LQ
# master::train() node12L-
# master::train() node11RG
# master::train() node11L-
# master::train() node10R-
# master::train() node9RQ
# master::train() node9LQ
# master::train() node10LG
# master::train() node13L-
# master::train() node12RQ
# master::train() node12LG
# master::train() node15L-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RG
# master::train() node13L-
# master::train() node12RQ
# master::train() node12LG
# master::train() node16L-
# master::train() node15RG
# master::train() node15LQ
# master::train() node19L-
# master::train() node18R-
# master::train() node17R-
# master::train() node16R-
# master::train() node15R-
# master::train() node14R-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RG
# master::train() node11LG
# master::train() node12L-
# master::train() node11R-
# master::train() node10R-
# master::train() node9RG
# master::train() node9LQ
# master::train() node10LG
# master::train() node11L-
# master::train() node10RG
# master::train() node10LG
# master::train() node13L-
# master::train() node12R-
# master::train() node11R-
# master::train() node10RG
# master::train() node10L-
# master::train() node9R-
# master::train() node8RG
# master::train() node8LQ
# master::train() node9LG
# master::train() node11L-
# master::train() node10RG
# master::train() node10L-
# master::train() node9RQ
# master::train() node9LQ
# master::train() node12L-
# master::train() node11RG
# master::train() node11LG
# master::train() node14L-
# master::train() node13R-
# master::train() node12R-
# master::train() node11R-
# master::train() node10R-
# master::train() node9RQ
# master::train() node9LG
# master::train() node10L-
# master::train() node9RG
# master::train() node9L-
# master::train() node8RG
# master::train() node8LQ
# master::train() node11L-
# master::train() node10RG
# master::train() node10L-
# master::train() node9R-
# master::train() node8R-
# master::train() node7RQ
# master::train() node7LQ
# master::train() node8LG
# master::train() node9L-
# master::train() node8RG
# master::train() node8LG
# master::train() node12L-
# master::train() node11R-
# master::train() node10R-
# master::train() node9RG
# master::train() node9L-
# master::train() node8RG
# master::train() node8L-
# master::train() node7RQ
# master::train() node7L-
# master::train() node6RG
# master::train() node6LQ
# master::train() node10L-
# master::train() node9R-
# master::train() node8RG
# master::train() node8LG
# master::train() node9LG
# master::train() node11L-
# master::train() node10R-
# master::train() node9RG
# master::train() node9L-
# master::train() node8RG
# master::train() node8LG
# master::train() node10L-
# master::train() node9R-
# master::train() node8R-
# master::train() node7RG
# master::train() node7LG
# master::train() node8L-
# master::train() node7R-
# master::train() node6R-
# master::train() node5RG
# master::train() node5L-
# master::train() node4RG
# master::train() node4LQ
# master::train() node6LG
# master::train() node7LG
# master::train() node9L-
# master::train() node8RQ
# master::train() node8L-
# master::train() node7RG
# master::train() node7LQ
# master::train() node13L-
# master::train() node12R-
# master::train() node11R-
# master::train() node10R-
# master::train() node9RG
# master::train() node9LG
# master::train() node10L-
# master::train() node9R-
# master::train() node8R-
# master::train() node7R-
# master::train() node6RG
# master::train() node6LG
# master::train() node7LG
# master::train() node8L-
# master::train() node7R-
# master::train() node6RQ
# master::train() node6LQ
# master::train() node7L-
# master::train() node6R-
# master::train() node5RG
# master::train() node5LQ
# master::train() node6LG
# master::train() node9L-
# master::train() node8R-
# master::train() node7RG
# master::train() node7LG
# master::train() node8L-
# master::train() node7R-
# master::train() node6RQ
# master::train() node6LG
# master::train() node7LG
# master::train() node11L-
# master::train() node10R-
# master::train() node9R-
# master::train() node8RQ
# master::train() node8LG
# master::train() node9L-
# master::train() node8RG
# master::train() node8LG
# master::train() node10L-
# master::train() node9R-
# master::train() node8R-
# master::train() node7RG
# master::train() node7LG
# master::train() node8L-
# master::train() node7RG
# master::train() node7LG
# master::train() node9L-
# master::train() node8R-
# master::train() node7RQ
# master::train() node7LQ
# master::train() node8L-
# master::train() node7R-
# master::train() node6RG
# master::train() node6LG
# master::train() node7LG
# master::train() node12L-
# master::train() node11R-
# master::train() node10RG
# master::train() node10L-
# master::train() node9RG
# master::train() node9LQ
# master::train() node11L-
# master::train() node10R-
# master::train() node9R-
# master::train() node8RG
# master::train() node8LG
# master::train() node9LG
# master::train() node10LQ
# master::train() node15L-
# master::train() node14R-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RG
# master::train() node11LQ
# master::train() node12L-
# master::train() node11RG
# master::train() node11LQ
# master::train() node13L-
# master::train() node12R-
# master::train() node11R-
# master::train() node10R-
# master::train() node9RG
# master::train() node9L-
# master::train() node8R-
# master::train() node7RQ
# master::train() node7LG
# master::train() node8L-
# master::train() node7RQ
# master::train() node7LQ
# master::train() node10LG
# master::train() node11L-
# master::train() node10RG
# master::train() node10L-
# master::train() node9RG
# master::train() node9LG
# master::train() node12LG
# master::train() node14L-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RG
# master::train() node11LG
# master::train() node12L-
# master::train() node11RG
# master::train() node11LQ
# master::train() node13L-
# master::train() node12R-
# master::train() node11R-
# master::train() node10R-
# master::train() node9R-
# master::train() node8RG
# master::train() node8LG
# master::train() node9L-
# master::train() node8RQ
# master::train() node8LG
# master::train() node10L-
# master::train() node9R-
# master::train() node8RG
# master::train() node8LQ
# master::train() node9LG
# master::train() node11L-
# master::train() node10R-
# master::train() node9RQ
# master::train() node9LG
# master::train() node10LQ
# master::train() node12L-
# master::train() node11R-
# master::train() node10RG
# master::train() node10LQ
# master::train() node11LG
# master::train() node16L-
# master::train() node15R-
# master::train() node14R-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RG
# master::train() node11LG
# master::train() node12L-
# master::train() node11RG
# master::train() node11LQ
# master::train() node13L-
# master::train() node12RG
# master::train() node12LG
# master::train() node14L-
# master::train() node13RG
# master::train() node13L-
# master::train() node12RG
# master::train() node12LQ
# master::train() node15L-
# master::train() node14R-
# master::train() node13R-
# master::train() node12R-
# master::train() node11RQ
# master::train() node11LG
# master::train() node12L-
# master::train() node11RG
# master::train() node11L-
# master::train() node10RG
# master::train() node10L-
# master::train() node9RG
# master::train() node9LQ
# master::train() node13L-
# master::train() node12RQ
# master::train() node12LG
# master::train() node14L-
# master::train() node13R-
# master::train() node12R-
# master::train() node11R-
# master::train() node10RG
# master::train() node10LQ
# master::train() node11L-
# master::train() node10RG
# master::train() node10LG
# master::train() node12L-
# master::train() node11RG
# master::train() node11L-
# master::train() node10R-
# master::train() node9RG
# master::train() node9LG
# master::train() node10LG
# master::train() node13L-
# master::train() node12RQ
# master::train() node12LG
# master::train() node17L-
# master::train() node16R-
# master::train() node15R-
# master::train() node14R-
# master::train() node13RG
# master::train() node13L-
# master::train() node12RG
# master::train() node12L-
# master::train() node11RQ
# master::train() node11LG
# master::train() node14L-
# master::train() node13R-
# master::train() node12RQ
# master::train() node12LG
# master::train() node13LQ
# master::train() node15L-
# master::train() node14RG
# master::train() node14LG
# master::train() node16L-
# master::train() node15RG
# master::train() node15L-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RQ
# master::train() node13LG
# master::train() node18L-
# master::train() node17R-
# master::train() node16R-
# master::train() node15RQ
# master::train() node15L-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RG
# master::train() node13LQ
# master::train() node16L-
# master::train() node15R-
# master::train() node14R-
# master::train() node13R-
# master::train() node12RQ
# master::train() node12L-
# master::train() node11RQ
# master::train() node11LG
# master::train() node13L-
# master::train() node12RG
# master::train() node12LQ
# master::train() node14L-
# master::train() node13RG
# master::train() node13L-
# master::train() node12R-
# master::train() node11RG
# master::train() node11LG
# master::train() node12L-
# master::train() node11RG
# master::train() node11LG
# master::train() node15LG
# master::train() node17L-
# master::train() node16R-
# master::train() node15R-
# master::train() node14RQ
# master::train() node14LG
# master::train() node15LG
# master::train() node16L-
# master::train() node15R-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RG
# master::train() node13LG
# master::train() node15L-
# master::train() node14RG
# master::train() node14L-
# master::train() node13RQ
# master::train() node13LQ

# %% [markdown]
# ##Write and read the tree
# You may need to save/load the tree to/from a pickle file

# %%
with open('out_tree.pic', 'wb') as pickleFile:
    pickle.dump(m.root, pickleFile, pickle.HIGHEST_PROTOCOL)
    
with open('out_tree.pic', 'rb') as pickleFile:
    root = pickle.load(pickleFile)

# %% [markdown]
# ##Check the file size

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A8BF-C894
#
#  Directory of C:\Users\Wasit\Documents\GitHub\parallel_forest\nb
#
# 07/04/2016  18:46    <DIR>          .
# 07/04/2016  18:46    <DIR>          ..
# 07/04/2016  18:07    <DIR>          .ipynb_checkpoints
# 26/02/2016  11:53    <DIR>          dataset
# 07/04/2016  18:32    <DIR>          myTrain
# 07/04/2016  18:46            87,493 out_tree.pic
# 26/02/2016  11:53           151,180 parallel forest.ipynb
# 07/04/2016  18:44            55,748 parallel forest-Copy1.ipynb
# 26/02/2016  11:53                16 run.bat
# 07/12/2015  15:20    <DIR>          train
# 26/02/2016  11:53                78 Untitled.ipynb
#                5 File(s)        294,515 bytes
#                6 Dir(s)  76,390,125,568 bytes free

# %% [markdown]
# ##The result decision tree
# Termination code (Q:min bag size, G:no information gain, D:reaching maximum depth)

# %%
from pforest.dataset import dataset
from pforest.tree import tree

#init the test tree
t=tree()
t.settree(root)
t.show()
# Out:
# Found pforest
# *- 20 H:2.322e+00,Q:004000 tau:0.537225604057 theta:[ 1.]
# L- 19 H:2.312e+00,Q:003521 tau:-0.591981470585 theta:[ 0.]
# RQ 13 H:5.924e-36,Q:000004 (cl,P):(003,0.75) (002,0.25) (004,0.00)
# RG 14 H:4.945e-36,Q:000006 (cl,P):(002,0.83) (003,0.17) (004,0.00)
# R- 15 H:4.768e-02,Q:000109 tau:0.937921464443 theta:[ 1.]
# LG 14 H:4.647e-37,Q:000105 (cl,P):(002,1.00) (004,0.00) (003,0.00)
# RG 14 H:4.455e-36,Q:000004 (cl,P):(002,0.75) (001,0.25) (004,0.00)
# R- 16 H:2.504e-01,Q:000011 tau:0.954961538315 theta:[ 1.]
# LQ 15 H:5.924e-36,Q:000003 (cl,P):(002,0.67) (001,0.33) (004,0.00)
# RG 15 H:2.983e-36,Q:000008 (cl,P):(001,1.00) (004,0.00) (003,0.00)
# R- 17 H:7.706e-01,Q:000056 tau:0.321947187185 theta:[ 0.]
# L- 16 H:5.355e-01,Q:000021 tau:0.825495898724 theta:[ 1.]
# LG 15 H:2.981e-36,Q:000014 (cl,P):(002,1.00) (004,0.00) (003,0.00)
# R- 15 H:2.857e-01,Q:000007 tau:0.262536257505 theta:[ 0.]
# LQ 14 H:5.924e-36,Q:000003 (cl,P):(001,1.00) (004,0.00) (003,0.00)
# RQ 14 H:5.924e-36,Q:000004 (cl,P):(001,0.75) (002,0.25) (004,0.00)
# R- 16 H:2.229e-01,Q:000035 tau:0.805785655975 theta:[ 1.]
# L- 15 H:2.504e-01,Q:000011 tau:0.456933259964 theta:[ 0.]
# LQ 14 H:5.924e-36,Q:000002 (cl,P):(002,1.00) (004,0.00) (003,0.00)
# RG 14 H:3.312e-36,Q:000009 (cl,P):(001,1.00) (004,0.00) (003,0.00)
# RG 15 H:1.998e-36,Q:000024 (cl,P):(001,1.00) (004,0.00) (003,0.00)

# %% [markdown]
# ## Recall rate
# Loading a new dataset, the last on, for computing a recall rate

# %%
#load the last dataset that never use for training
dset=dataset(8)
correct=0;
for x in xrange(dset.size):
    L=t.getL(np.array([x]),dset)
    if dset.getL(x) == L:
        correct=correct+1
    dset.setL(x,L)
print("recall rate: {}%".format(correct/float(dset.size)*100))
# Out:
# recall rate: 94.84%

# %% [markdown]
# ## Labelling
# The computer use the decision tree to classify the unknown feature vector u

# %%
#setup the new test-set
#load dataset     
dset=dataset(8)
d=0.05
y, x = np.mgrid[slice(-1, 1+d, d), slice(-1, 1+d, d)]

#start labeling
L=np.zeros(x.shape,dtype=int)
for r in xrange(x.shape[0]):
    for c in xrange(x.shape[1]):
        u=( x[r,c],y[r,c] )
        Prob=t.classify(u)
        L[r,c]=np.argmax(Prob)

# %% [markdown]
# ##2D space partitioning by the decision tree
# Displaying the labelled result

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.axis([-1,1,-1,1])
ax.pcolor(x,y,L)
ax.hold(True)

# %% [markdown]
# #Overlay the dataset

# %%
z=np.random.randint(0,dset.size,1000)
for i in z:
    ax.plot(dset.I[i,0],dset.I[i,1],marker[dset.samples[i]])
fig

# %%
t.classify([0.75,0.0])
# Out:
# array([ 0.,  1.,  0.,  0.,  0.])
